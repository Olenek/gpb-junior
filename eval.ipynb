# %% [markdown]
# ### Грузим строки оставленные в Тест множестве

# %%
import joblib
import pandas as pd
from src.OLS import *

df = pd.read_csv('data/realty_data.csv', encoding='utf-8').drop(columns='period')
df['product_name'] = df.product_name.str.replace(' ', ' ')
rs_coord = (55.7539, 37.6208)

df['rs_dist'] = (df['lat'] - rs_coord[0]) ** 2 + (df['lon'] - rs_coord[1]) ** 2

reg_pipe = joblib.load('pipe.pkl')
clusterer = joblib.load('clusterer.pkl')
train_index = joblib.load('train_index.pkl')
preds = joblib.load('preds.pkl')

df = df[~df.index.isin(train_index)].reset_index(drop=True)
df
# Out:
#                 product_name      price  postcode  \
# 0        3-комнатная, 137 м²   63000000  127473.0
# 1         3-комнатная, 76 м²   16004680       NaN
# 2         1-комнатная, 24 м²    7841776       NaN
# 3       1-комнатная, 34,8 м²    7200000  140016.0
# 4      3-комнатная, 154,7 м²  170663394  123242.0
# ...                      ...        ...       ...
# 19760     2-комнатная, 56 м²   11655000  108811.0
# 19761     3-комнатная, 75 м²   53000000  123104.0
# 19762   2-комнатная, 47,7 м²   12999999  125481.0
# 19763   1-комнатная, 33,5 м²    8500000  108823.0
# 19764     3-комнатная, 56 м²   15999000  109518.0
#
#                           address_name        lat        lon object_type  \
# 0         2-й Щемиловский переулок, 5а  55.778894  37.608844    Квартира
# 1                    ЖК Прокшино, 8 к4  55.594802  37.431264    Квартира
# 2                    ЖК Прокшино, 6 к2  55.594332  37.428099    Квартира
# 3                        Дружбы, 11/26  55.701957  37.966424    Квартира
# 4                  Дружинниковская, 15  55.759822  37.575351    Квартира
# ...                                ...        ...        ...         ...
# 19760  бульвар Андрея Тарковского, к15  55.625693  37.341506    Квартира
# 19761  Богословский переулок, 8/15 ст1  55.762616  37.599727    Квартира
# 19762                  Свободы, 81 ст5  55.860262  37.442163    Квартира
# 19763         Рязановское шоссе, 31 к1  55.476485  37.530099    Квартира
# 19764    1-й Грайвороновский проезд, 3  55.719431  37.724875    Квартира
#
#        total_square  rooms  floor     city settlement               district  \
# 0            137.00    3.0    6.0   Москва        NaN         Тверской район
# 1             76.00    3.0    6.0   Москва        NaN    Сосенское поселение
# 2             24.00    1.0   10.0   Москва        NaN    Сосенское поселение
# 3             34.80    1.0   16.0  Люберцы        NaN                    NaN
# 4            154.68    3.0   16.0   Москва        NaN      Пресненский район
# ...             ...    ...    ...      ...        ...                    ...
# 19760         56.00    2.0    3.0   Москва        NaN   Внуковское поселение
# 19761         75.00    3.0    2.0   Москва        NaN      Пресненский район
# 19762         47.70    2.0    4.0   Москва        NaN  Северное Тушино район
# 19763         33.50    1.0   13.0   Москва        NaN  Рязановское поселение
# 19764         56.00    3.0   11.0   Москва        NaN     Текстильщики район
#
#               area                                        description  \
# 0              NaN  Просторная квартира свободной планировки с пан...
# 1              NaN  Apт.1684018. 0,01% - гибкая ипотека! Воспользу...
# 2              NaN  Продается однокомнатная квартира № 381 в новос...
# 3      Самолёт м-н  Агентам просьба не беспокоить!\nПродаётся свет...
# 4              NaN  Предлагается трехкомнатная квартира в новом жи...
# ...            ...                                                ...
# 19760          NaN  Квартира расположена в Новой Москве, ЖК «Расск...
# 19761          NaN  Красивый фасадный дом. Потолки 3,4 м., без бал...
# 19762          NaN  К продаже представлена 2-х комнатная квартира ...
# 19763          NaN  Номер лота: вт-0398917.\nВашему вниманию предл...
# 19764          NaN  Новостройка! Евротрешка , две раздельная комна...
#
#                     source   rs_dist
# 0                     ЦИАН  0.000768
# 1      Яндекс.Недвижимость  0.061236
# 2              Новострой-М  0.062596
# 3                  Домклик  0.122154
# 4                  Домклик  0.002101
# ...                    ...       ...
# 19760  Яндекс.Недвижимость  0.094442
# 19761                 ЦИАН  0.000520
# 19762              Домклик  0.043224
# 19763              Домклик  0.085186
# 19764              Домклик  0.012020
#
# [19765 rows x 17 columns]

# %%
import numpy as np

df['price_pred'] = np.where(preds<0, 0, preds)
df['signed_error'] = df['price'] - df['price_pred']
df['error'] = np.abs(df['signed_error'])
df['error_perc'] = df['error'] / df['price'] * 100
df['error_quantile'] = pd.qcut(df['error'], 5, labels=False).astype(str)

# %%
to_plot = df[(df.price < df.price.quantile(.95)) & (df.error > df.error.quantile(.2))]

# %% [markdown]
# ### Карта распределения цен
#
# Ниже представлена карта предложений, которые модель *НЕ ВИДЕЛА* при обучении. Исключены точки с чрезмерно высокими ценами (более 80 миллионов, 5% наблюдений), а также выбросы предсказаний модели (2% предсказаний)

# %%
import plotly.express as px

fig = px.scatter_mapbox(to_plot,
                        lat="lat",
                        lon="lon",
                        height=600,
                        width=600,
                        color='price',
                        zoom=9,
                        mapbox_style='open-street-map')
fig.show()
# Out:
# <div>                            <div id="4a327f04-b3ee-4b27-b78d-05538c52033e" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a327f04-b3ee-4b27-b78d-05538c52033e")) {                    Plotly.newPlot(                        "4a327f04-b3ee-4b27-b78d-05538c52033e",                        [{"hovertemplate":"lat=%{lat}<br>lon=%{lon}<br>price=%{marker.color}<extra></extra>","lat":[55.778894,55.594802,55.594332,55.701957,55.926089,55.860761,55.793629,55.728307,55.723832,55.701303,55.624275,55.633336,55.593432,55.584005,55.732514,55.774497,55.715352,55.836104,55.473556,55.837418,55.561135,55.773989,55.848882,55.971599,55.799657,55.788624,55.548055,55.871218,55.818179,55.593432,55.899416,55.634659,55.814103,55.918816,55.785328,55.969172,55.860342,55.793036,55.754318,55.910155,55.728532,55.659298,55.595826,55.703001,55.95202,55.790495,55.716833,55.754318,55.793036,55.918816,56.010845,55.692916,55.822748,55.941075,55.84281,55.848882,55.843526,55.666623,55.714813,55.857965,55.701222,55.866381,55.715352,55.836991,55.876507,55.728307,55.605186,55.602643,55.780238,55.94501,55.836889,55.595427,55.732259,55.787206,55.54376,55.82013,55.687023,55.802277,55.842928,55.683002,55.531976,55.813543,55.790565,55.741711,55.622867,55.797873,55.825023,55.908536,55.725087,55.702876,55.727307,55.78255,55.774491,55.67238,55.569256,55.677851,55.864908,55.642207,55.999323,55.556172,55.682412,55.69724,55.798206,55.845411,55.789629,55.781606,55.503972,55.901173,55.832496,55.823294,55.653727,55.785328,55.559874,55.594031,55.913727,55.786306,55.720746,55.775774,55.746127,55.698032,55.66019,55.756348,55.822108,55.680277,55.659569,55.793598,55.74989,55.645447,56.005436,55.740288,55.719525,55.838184,55.806315,55.789934,55.717508,55.711328,55.836889,55.922615,55.673409,55.695239,55.865837,55.592014,55.726964,55.714346,55.722033,55.767753,55.753214,55.749502,55.601976,55.746127,55.774976,55.694708,55.622831,55.755766,55.918433,55.675973,55.552558,55.69164,55.689398,55.728138,55.680176,55.942
ary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.762
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                 1.684e+04
# Date:                Fri, 07 Apr 2023   Prob (F-statistic):               0.00
# Time:                        17:30:29   Log-Likelihood:            -1.4315e+06
# No. Observations:               79057   AIC:                         2.863e+06
# Df Residuals:                   79041   BIC:                         2.863e+06
# Df Model:                          15
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# C(cluster)[0.0]  -4.138e+06   3.97e+05    -10.423      0.000   -4.92e+06   -3.36e+06
# C(cluster)[1.0]    -4.8e+06   3.06e+05    -15.672      0.000    -5.4e+06    -4.2e+06
# C(cluster)[2.0]  -3.003e+06   4.26e+05     -7.057      0.000   -3.84e+06   -2.17e+06
# C(cluster)[3.0]   1.658e+06   3.14e+05      5.287      0.000    1.04e+06    2.27e+06
# C(cluster)[4.0]   3.766e+05   4.98e+05      0.756      0.450      -6e+05    1.35e+06
# C(cluster)[5.0]  -2.964e+06   2.61e+05    -11.337      0.000   -3.48e+06   -2.45e+06
# C(cluster)[6.0]   1.978e+06    5.9e+05      3.353      0.001    8.22e+05    3.13e+06
# C(cluster)[7.0]    6.85e+05   5.13e+05      1.335      0.182   -3.21e+05    1.69e+06
# C(cluster)[8.0]  -5.148e+06   4.04e+05    -12.757      0.000   -5.94e+06   -4.36e+06
# C(cluster)[9.0]  -3.189e+06    5.1e+05     -6.251      0.000   -4.19e+06   -2.19e+06
# C(cluster)[10.0]   6.65e+06   2.74e+05     24.228      0.000    6.11e+06    7.19e+06
# C(cluster)[11.0]  2.439e+05   4.77e+05      0.512      0.609    -6.9e+05    1.18e+06
# rs_dist          -6.741e+07    1.4e+06    -48.067      0.000   -7.02e+07   -6.47e+07
# total_square      5.857e+05   1363.079    429.666      0.000    5.83e+05    5.88e+05
# floor            -1.594e+05   2.02e+04     -7.888      0.000   -1.99e+05    -1.2e+05
# np.square(floor)  3922.0928    571.142      6.867      0.000    2802.659    5041.527
# ==============================================================================
# Omnibus:                    58479.900   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         35921919.514
# Skew:                           2.319   Prob(JB):                         0.00
# Kurtosis:                     107.325   Cond. No.                     9.75e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.75e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.metrics import r2_score, mean_squared_error

print(f'out-of-sample R2: {r2_score(df.price, df.price_pred)}, RMSE: {mean_squared_error(df.price, df.price_pred) ** 0.5}')
# Out:
# out-of-sample R2: 0.7592422183426217, RMSE: 17198378.949009344

# %% [markdown]
# В целом, модель объясняет 76% вариативности данных, что на 76% пунктов выше чем наивное предсказание==средняя цена.
# Модель состоит из двух частей - линейной регрессии (обученной по OLS), коэффиценты которой можно интепретировать так:
# - С увеличением расстояния от Красной Площади на 1 км, цена падает на 530 тысячи рублей
# - В среднем, один дополнительный квадратный метр стоит 580тыс рублей
# - В среднем, выбрать квартиру на X+1 этаже, стоит дешевле на 160 - 12 * X тысяч рублей (5 этаж стоит дешевле 4 на 110 тыс рублей)
# Над OLS моделью можно поработать, в частности над кластеризацией и заменить на более осмысленное разбиение по районам и использовать TSLS.
# -
# Также, в модель включен fine-tuned NLP модель на основе SBERT (обученная на ошибках OLS), однако ее вклад в предсказание минимален и нужно поработать над ней.
